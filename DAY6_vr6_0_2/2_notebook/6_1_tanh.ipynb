# %% [markdown]
# # tanh関数の確認

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5,5,0.1)
y = np.tanh(x)
plt.plot(x,y)
dy = (1-y**2)
plt.plot(x,dy)
plt.xlabel("x")
plt.ylabel("")
plt.legend(["y=tanh(x)","dy/dx=1-y^2"])
