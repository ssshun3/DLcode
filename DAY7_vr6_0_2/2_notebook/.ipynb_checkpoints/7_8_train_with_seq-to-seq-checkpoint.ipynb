# %% [markdown]
# # 系列変換モデルで学習する

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from common.seq2seq import Seq2seq # seq2seq
from common.attention_seq2seq import AttentionSeq2seq # アテンション付きseq2seq
from common.attention_biseq2seq import AttentionBiSeq2seq # エンコーダ側LSTMが双方向になったアテンション付きseq2seq

# %%
# データの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256
batch_size = 256
max_epoch = 20

# %% [markdown]
# ### モデルの選択
# モデルを切り替えて、結果を比較してみましょう

# %%
model = Seq2seq(vocab_size, wordvec_size, hidden_size)
# model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
# model = AttentionBiSeq2seq(vocab_size, wordvec_size, hidden_size)

# %% [markdown]
# ### 学習

# %%
# 最適化手法の設定
optimizer = Adam()

# 学習のオブジェクトを生成
trainer = Trainer(model, optimizer)

# 学習のループ
acc_list = []
loss_list = []
for epoch in range(max_epoch):
    
    # trainデータで1epoch分の計算
    trainer.fit(x_train, t_train, max_epoch=1,batch_size=batch_size)

    # testデータで精度を確認する
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose) 

    # 精度算出
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))

    # loss算出
    loss = model.forward(x_test, t_test)
    loss_list.append(loss)
    print('val loss %.3f' % (loss))
    
    # 重み保存
    model.save_params()
# Out:
# | epoch 1 |  iter 1 / 175 | time 0[s] | loss 4.07750
# | epoch 1 |  iter 21 / 175 | time 9[s] | loss 3.14722
# | epoch 1 |  iter 41 / 175 | time 18[s] | loss 1.89213
# | epoch 1 |  iter 61 / 175 | time 27[s] | loss 1.75640
# | epoch 1 |  iter 81 / 175 | time 37[s] | loss 1.64672
# | epoch 1 |  iter 101 / 175 | time 49[s] | loss 1.40444
# | epoch 1 |  iter 121 / 175 | time 59[s] | loss 1.17603
# | epoch 1 |  iter 141 / 175 | time 69[s] | loss 1.11429
# | epoch 1 |  iter 161 / 175 | time 79[s] | loss 1.07517
# Q 10/15/94
# T 1994-10-15
# ☒ 1997-01-20
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1997-01-20
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1997-01-20
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1997-01-20
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1997-01-20
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1997-01-20
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1997-01-20
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1997-01-20
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1997-01-20
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1997-01-20
# ---
# val acc 0.000%
# val loss 1.051
# | epoch 2 |  iter 1 / 175 | time 0[s] | loss 1.05106
# | epoch 2 |  iter 21 / 175 | time 10[s] | loss 1.04369
# | epoch 2 |  iter 41 / 175 | time 20[s] | loss 1.03683
# | epoch 2 |  iter 61 / 175 | time 29[s] | loss 1.03146
# | epoch 2 |  iter 81 / 175 | time 38[s] | loss 1.02606
# | epoch 2 |  iter 101 / 175 | time 49[s] | loss 1.02016
# | epoch 2 |  iter 121 / 175 | time 59[s] | loss 1.01459
# | epoch 2 |  iter 141 / 175 | time 70[s] | loss 1.00837
# | epoch 2 |  iter 161 / 175 | time 80[s] | loss 1.00367
# Q 10/15/94
# T 1994-10-15
# ☒ 1999-06-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1999-06-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1999-06-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1999-06-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1999-06-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1999-06-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1999-06-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1999-06-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1999-06-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1999-06-21
# ---
# val acc 0.000%
# val loss 1.001
# | epoch 3 |  iter 1 / 175 | time 0[s] | loss 1.00203
# | epoch 3 |  iter 21 / 175 | time 10[s] | loss 0.99745
# | epoch 3 |  iter 41 / 175 | time 19[s] | loss 0.99430
# | epoch 3 |  iter 61 / 175 | time 28[s] | loss 0.99409
# | epoch 3 |  iter 81 / 175 | time 37[s] | loss 0.99216
# | epoch 3 |  iter 101 / 175 | time 46[s] | loss 0.99067
# | epoch 3 |  iter 121 / 175 | time 56[s] | loss 0.98881
# | epoch 3 |  iter 141 / 175 | time 65[s] | loss 0.98881
# | epoch 3 |  iter 161 / 175 | time 74[s] | loss 0.98834
# Q 10/15/94
# T 1994-10-15
# ☒ 1986-07-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1986-07-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1986-07-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1986-07-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1986-07-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1986-07-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1986-07-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1986-07-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1986-07-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1986-07-21
# ---
# val acc 0.000%
# val loss 0.988
# | epoch 4 |  iter 1 / 175 | time 0[s] | loss 0.99137
# | epoch 4 |  iter 21 / 175 | time 9[s] | loss 0.98635
# | epoch 4 |  iter 41 / 175 | time 19[s] | loss 0.98663
# | epoch 4 |  iter 61 / 175 | time 28[s] | loss 0.98561
# | epoch 4 |  iter 81 / 175 | time 38[s] | loss 0.98626
# | epoch 4 |  iter 101 / 175 | time 47[s] | loss 0.98483
# | epoch 4 |  iter 121 / 175 | time 57[s] | loss 0.98583
# | epoch 4 |  iter 141 / 175 | time 67[s] | loss 0.98573
# | epoch 4 |  iter 161 / 175 | time 77[s] | loss 0.98508
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-04-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-04-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-04-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1978-04-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1978-04-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1978-04-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1978-04-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1978-04-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1978-04-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1978-04-21
# ---
# val acc 0.000%
# val loss 0.984
# | epoch 5 |  iter 1 / 175 | time 0[s] | loss 0.98462
# | epoch 5 |  iter 21 / 175 | time 10[s] | loss 0.98462
# | epoch 5 |  iter 41 / 175 | time 19[s] | loss 0.98510
# | epoch 5 |  iter 61 / 175 | time 28[s] | loss 0.98402
# | epoch 5 |  iter 81 / 175 | time 37[s] | loss 0.98436
# | epoch 5 |  iter 101 / 175 | time 45[s] | loss 0.98430
# | epoch 5 |  iter 121 / 175 | time 54[s] | loss 0.98411
# | epoch 5 |  iter 141 / 175 | time 63[s] | loss 0.98367
# | epoch 5 |  iter 161 / 175 | time 72[s] | loss 0.98365
# Q 10/15/94
# T 1994-10-15
# ☒ 1973-01-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1973-01-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1973-01-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1973-01-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1973-01-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1973-01-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1973-01-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1973-01-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1973-01-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1973-01-21
# ---
# val acc 0.000%
# val loss 0.986
# | epoch 6 |  iter 1 / 175 | time 0[s] | loss 0.97924
# | epoch 6 |  iter 21 / 175 | time 10[s] | loss 0.98364
# | epoch 6 |  iter 41 / 175 | time 19[s] | loss 0.98345
# | epoch 6 |  iter 61 / 175 | time 28[s] | loss 0.98220
# | epoch 6 |  iter 81 / 175 | time 37[s] | loss 0.98189
# | epoch 6 |  iter 101 / 175 | time 45[s] | loss 0.98354
# | epoch 6 |  iter 121 / 175 | time 54[s] | loss 0.98219
# | epoch 6 |  iter 141 / 175 | time 63[s] | loss 0.98270
# | epoch 6 |  iter 161 / 175 | time 72[s] | loss 0.98275
# Q 10/15/94
# T 1994-10-15
# ☒ 1988-03-23
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1988-03-23
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1988-03-23
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1988-03-23
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1988-03-23
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1988-03-23
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1988-03-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1988-03-23
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1988-03-23
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1988-03-23
# ---
# val acc 0.000%
# val loss 0.982
# | epoch 7 |  iter 1 / 175 | time 0[s] | loss 0.98311
# | epoch 7 |  iter 21 / 175 | time 9[s] | loss 0.98282
# | epoch 7 |  iter 41 / 175 | time 18[s] | loss 0.98238
# | epoch 7 |  iter 61 / 175 | time 27[s] | loss 0.98204
# | epoch 7 |  iter 81 / 175 | time 36[s] | loss 0.98205
# | epoch 7 |  iter 101 / 175 | time 44[s] | loss 0.98192
# | epoch 7 |  iter 121 / 175 | time 53[s] | loss 0.98206
# | epoch 7 |  iter 141 / 175 | time 62[s] | loss 0.98182
# | epoch 7 |  iter 161 / 175 | time 71[s] | loss 0.98182
# Q 10/15/94
# T 1994-10-15
# ☒ 1999-01-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1999-01-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1999-01-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1999-01-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1999-01-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1999-01-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1999-01-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1999-01-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1999-01-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1999-01-21
# ---
# val acc 0.000%
# val loss 0.983
# | epoch 8 |  iter 1 / 175 | time 0[s] | loss 0.98421
# | epoch 8 |  iter 21 / 175 | time 9[s] | loss 0.98161
# | epoch 8 |  iter 41 / 175 | time 18[s] | loss 0.98265
# | epoch 8 |  iter 61 / 175 | time 27[s] | loss 0.98066
# | epoch 8 |  iter 81 / 175 | time 36[s] | loss 0.98129
# | epoch 8 |  iter 101 / 175 | time 44[s] | loss 0.98123
# | epoch 8 |  iter 121 / 175 | time 53[s] | loss 0.98152
# | epoch 8 |  iter 141 / 175 | time 62[s] | loss 0.98184
# | epoch 8 |  iter 161 / 175 | time 71[s] | loss 0.98148
# Q 10/15/94
# T 1994-10-15
# ☒ 1982-07-17
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1982-07-17
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1982-07-17
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1982-07-17
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1982-07-17
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1982-07-17
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1982-07-17
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1982-07-17
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1982-07-17
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1982-07-17
# ---
# val acc 0.020%
# val loss 0.982
# | epoch 9 |  iter 1 / 175 | time 0[s] | loss 0.98410
# | epoch 9 |  iter 21 / 175 | time 9[s] | loss 0.98129
# | epoch 9 |  iter 41 / 175 | time 18[s] | loss 0.98097
# | epoch 9 |  iter 61 / 175 | time 27[s] | loss 0.98017
# | epoch 9 |  iter 81 / 175 | time 36[s] | loss 0.98146
# | epoch 9 |  iter 101 / 175 | time 44[s] | loss 0.98128
# | epoch 9 |  iter 121 / 175 | time 53[s] | loss 0.98135
# | epoch 9 |  iter 141 / 175 | time 62[s] | loss 0.98077
# | epoch 9 |  iter 161 / 175 | time 71[s] | loss 0.98207
# Q 10/15/94
# T 1994-10-15
# ☒ 1992-09-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1992-09-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1992-09-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1992-09-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1992-09-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1992-09-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1992-09-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1992-09-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1992-09-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1992-09-21
# ---
# val acc 0.000%
# val loss 0.984
# | epoch 10 |  iter 1 / 175 | time 0[s] | loss 0.98165
# | epoch 10 |  iter 21 / 175 | time 9[s] | loss 0.98134
# | epoch 10 |  iter 41 / 175 | time 18[s] | loss 0.98002
# | epoch 10 |  iter 61 / 175 | time 27[s] | loss 0.98031
# | epoch 10 |  iter 81 / 175 | time 36[s] | loss 0.98113
# | epoch 10 |  iter 101 / 175 | time 45[s] | loss 0.98150
# | epoch 10 |  iter 121 / 175 | time 54[s] | loss 0.98099
# | epoch 10 |  iter 141 / 175 | time 63[s] | loss 0.98074
# | epoch 10 |  iter 161 / 175 | time 72[s] | loss 0.98223
# Q 10/15/94
# T 1994-10-15
# ☒ 1996-04-14
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1996-04-14
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1996-04-14
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1996-04-14
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1996-04-14
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1996-04-14
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1996-04-14
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1996-04-14
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1996-04-14
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1996-04-14
# ---
# val acc 0.000%
# val loss 0.981
# | epoch 11 |  iter 1 / 175 | time 0[s] | loss 0.98048
# | epoch 11 |  iter 21 / 175 | time 9[s] | loss 0.98128
# | epoch 11 |  iter 41 / 175 | time 18[s] | loss 0.98122
# | epoch 11 |  iter 61 / 175 | time 27[s] | loss 0.98115
# | epoch 11 |  iter 81 / 175 | time 36[s] | loss 0.98107
# | epoch 11 |  iter 101 / 175 | time 44[s] | loss 0.98132
# | epoch 11 |  iter 121 / 175 | time 53[s] | loss 0.98073
# | epoch 11 |  iter 141 / 175 | time 62[s] | loss 0.98100
# | epoch 11 |  iter 161 / 175 | time 71[s] | loss 0.98113
# Q 10/15/94
# T 1994-10-15
# ☒ 1970-04-14
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1970-04-14
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1970-04-14
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1970-04-14
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1970-04-14
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1970-04-14
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1970-04-14
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1970-04-14
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1970-04-14
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1970-04-14
# ---
# val acc 0.020%
# val loss 0.981
# | epoch 12 |  iter 1 / 175 | time 0[s] | loss 0.98026
# | epoch 12 |  iter 21 / 175 | time 9[s] | loss 0.98079
# | epoch 12 |  iter 41 / 175 | time 18[s] | loss 0.98160
# | epoch 12 |  iter 61 / 175 | time 27[s] | loss 0.98077
# | epoch 12 |  iter 81 / 175 | time 36[s] | loss 0.98111
# | epoch 12 |  iter 101 / 175 | time 44[s] | loss 0.98093
# | epoch 12 |  iter 121 / 175 | time 53[s] | loss 0.98165
# | epoch 12 |  iter 141 / 175 | time 62[s] | loss 0.98130
# | epoch 12 |  iter 161 / 175 | time 71[s] | loss 0.98115
# Q 10/15/94
# T 1994-10-15
# ☒ 1999-03-23
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1999-03-23
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1999-03-23
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1999-03-23
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1999-03-23
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1999-03-23
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1999-03-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1999-03-23
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1999-03-23
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1999-03-23
# ---
# val acc 0.000%
# val loss 0.981
# | epoch 13 |  iter 1 / 175 | time 0[s] | loss 0.97984
# | epoch 13 |  iter 21 / 175 | time 9[s] | loss 0.98090
# | epoch 13 |  iter 41 / 175 | time 19[s] | loss 0.98019
# | epoch 13 |  iter 61 / 175 | time 28[s] | loss 0.98054
# | epoch 13 |  iter 81 / 175 | time 36[s] | loss 0.98015
# | epoch 13 |  iter 101 / 175 | time 45[s] | loss 0.98054
# | epoch 13 |  iter 121 / 175 | time 54[s] | loss 0.98083
# | epoch 13 |  iter 141 / 175 | time 63[s] | loss 0.98068
# | epoch 13 |  iter 161 / 175 | time 71[s] | loss 0.98037
# Q 10/15/94
# T 1994-10-15
# ☒ 1999-05-20
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1999-05-20
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1999-05-20
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1999-05-20
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1999-05-20
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1999-05-20
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1999-05-20
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1999-05-20
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1999-05-20
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1999-05-20
# ---
# val acc 0.000%
# val loss 0.980
# | epoch 14 |  iter 1 / 175 | time 0[s] | loss 0.98233
# | epoch 14 |  iter 21 / 175 | time 9[s] | loss 0.97958
# | epoch 14 |  iter 41 / 175 | time 18[s] | loss 0.98034
# | epoch 14 |  iter 61 / 175 | time 27[s] | loss 0.98045
# | epoch 14 |  iter 81 / 175 | time 36[s] | loss 0.98038
# | epoch 14 |  iter 101 / 175 | time 45[s] | loss 0.98065
# | epoch 14 |  iter 121 / 175 | time 53[s] | loss 0.98007
# | epoch 14 |  iter 141 / 175 | time 62[s] | loss 0.97972
# | epoch 14 |  iter 161 / 175 | time 71[s] | loss 0.97993
# Q 10/15/94
# T 1994-10-15
# ☒ 1999-03-23
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1999-03-23
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1999-03-23
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1999-03-23
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1999-03-23
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1999-03-23
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1999-03-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1999-03-23
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1999-03-23
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1999-03-23
# ---
# val acc 0.000%
# val loss 0.980
# | epoch 15 |  iter 1 / 175 | time 0[s] | loss 0.98047
# | epoch 15 |  iter 21 / 175 | time 9[s] | loss 0.98075
# | epoch 15 |  iter 41 / 175 | time 18[s] | loss 0.98047
# | epoch 15 |  iter 61 / 175 | time 27[s] | loss 0.98078
# | epoch 15 |  iter 81 / 175 | time 36[s] | loss 0.97969
# | epoch 15 |  iter 101 / 175 | time 44[s] | loss 0.97946
# | epoch 15 |  iter 121 / 175 | time 53[s] | loss 0.98036
# | epoch 15 |  iter 141 / 175 | time 62[s] | loss 0.97985
# | epoch 15 |  iter 161 / 175 | time 71[s] | loss 0.98024
# Q 10/15/94
# T 1994-10-15
# ☒ 1979-05-25
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1979-05-25
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1979-05-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1979-05-25
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1979-05-25
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1979-05-25
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1979-05-25
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1979-05-25
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1979-05-25
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1979-05-25
# ---
# val acc 0.000%
# val loss 0.981
# | epoch 16 |  iter 1 / 175 | time 0[s] | loss 0.98058
# | epoch 16 |  iter 21 / 175 | time 9[s] | loss 0.98046
# | epoch 16 |  iter 41 / 175 | time 18[s] | loss 0.97955
# | epoch 16 |  iter 61 / 175 | time 27[s] | loss 0.97983
# | epoch 16 |  iter 81 / 175 | time 36[s] | loss 0.98038
# | epoch 16 |  iter 101 / 175 | time 44[s] | loss 0.98062
# | epoch 16 |  iter 121 / 175 | time 53[s] | loss 0.98063
# | epoch 16 |  iter 141 / 175 | time 62[s] | loss 0.97973
# | epoch 16 |  iter 161 / 175 | time 71[s] | loss 0.97955
# Q 10/15/94
# T 1994-10-15
# ☒ 1980-07-13
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1980-07-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1980-07-13
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1980-07-13
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1980-07-13
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1980-07-13
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1980-07-13
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1980-07-13
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1980-07-13
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1980-07-13
# ---
# val acc 0.000%
# val loss 0.979
# | epoch 17 |  iter 1 / 175 | time 0[s] | loss 0.97938
# | epoch 17 |  iter 21 / 175 | time 9[s] | loss 0.97972
# | epoch 17 |  iter 41 / 175 | time 18[s] | loss 0.98025
# | epoch 17 |  iter 61 / 175 | time 27[s] | loss 0.97984
# | epoch 17 |  iter 81 / 175 | time 36[s] | loss 0.98044
# | epoch 17 |  iter 101 / 175 | time 46[s] | loss 0.98027
# | epoch 17 |  iter 121 / 175 | time 55[s] | loss 0.97941
# | epoch 17 |  iter 141 / 175 | time 63[s] | loss 0.97950
# | epoch 17 |  iter 161 / 175 | time 76[s] | loss 0.98030
# Q 10/15/94
# T 1994-10-15
# ☒ 1985-08-20
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1985-08-20
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1985-08-20
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1985-08-20
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1985-08-20
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1985-08-20
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1985-08-20
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1985-08-20
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1985-08-20
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1985-08-20
# ---
# val acc 0.000%
# val loss 0.981
# | epoch 18 |  iter 1 / 175 | time 1[s] | loss 0.98026
# | epoch 18 |  iter 21 / 175 | time 18[s] | loss 0.97936
# | epoch 18 |  iter 41 / 175 | time 35[s] | loss 0.97926
# | epoch 18 |  iter 61 / 175 | time 52[s] | loss 0.97936
# | epoch 18 |  iter 81 / 175 | time 68[s] | loss 0.97985
# | epoch 18 |  iter 101 / 175 | time 85[s] | loss 0.98005
# | epoch 18 |  iter 121 / 175 | time 102[s] | loss 0.97948
# | epoch 18 |  iter 141 / 175 | time 119[s] | loss 0.97964
# | epoch 18 |  iter 161 / 175 | time 136[s] | loss 0.97978
# Q 10/15/94
# T 1994-10-15
# ☒ 1970-05-14
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1970-05-14
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1970-05-14
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1970-05-14
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1970-05-14
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1970-05-14
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1970-05-14
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1970-05-14
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1970-05-14
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1970-05-14
# ---
# val acc 0.000%
# val loss 0.980
# | epoch 19 |  iter 1 / 175 | time 2[s] | loss 0.98071
# | epoch 19 |  iter 21 / 175 | time 44[s] | loss 0.97979
# | epoch 19 |  iter 41 / 175 | time 80[s] | loss 0.97917
# | epoch 19 |  iter 61 / 175 | time 123[s] | loss 0.97928
# | epoch 19 |  iter 81 / 175 | time 164[s] | loss 0.97921
# | epoch 19 |  iter 101 / 175 | time 207[s] | loss 0.97960
# | epoch 19 |  iter 121 / 175 | time 249[s] | loss 0.98065
# | epoch 19 |  iter 141 / 175 | time 286[s] | loss 0.98012
# | epoch 19 |  iter 161 / 175 | time 324[s] | loss 0.98024
# Q 10/15/94
# T 1994-10-15
# ☒ 1980-01-21
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1980-01-21
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1980-01-21
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1980-01-21
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1980-01-21
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1980-01-21
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1980-01-21
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1980-01-21
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1980-01-21
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1980-01-21
# ---
# val acc 0.000%
# val loss 0.981
# | epoch 20 |  iter 1 / 175 | time 0[s] | loss 0.97868
# | epoch 20 |  iter 21 / 175 | time 9[s] | loss 0.97913
# | epoch 20 |  iter 41 / 175 | time 18[s] | loss 0.98010
# | epoch 20 |  iter 61 / 175 | time 27[s] | loss 0.97910
# | epoch 20 |  iter 81 / 175 | time 36[s] | loss 0.97950
# | epoch 20 |  iter 101 / 175 | time 45[s] | loss 0.97894
# | epoch 20 |  iter 121 / 175 | time 54[s] | loss 0.97918
# | epoch 20 |  iter 141 / 175 | time 63[s] | loss 0.97975
# | epoch 20 |  iter 161 / 175 | time 72[s] | loss 0.97952
# Q 10/15/94
# T 1994-10-15
# ☒ 1970-08-03
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1970-08-03
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1970-08-03
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1970-08-03
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1970-08-03
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1970-08-03
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1970-08-03
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1970-08-03
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1970-08-03
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1970-08-03
# ---
# val acc 0.000%
# val loss 0.982

# %%
# Accuracyの描画
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim(-0.05, 1.05)
plt.show()

# Lossの描画
plt.plot(x, loss_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('loss')
# plt.ylim(-0.05, 0.1)
plt.show()

# %% [markdown]
# ### [演習]
# * Seq2seq、AttentionSeq2seq、AttentionBiSeq2seqのそれぞれの場合を計算し、結果を比較してみましょう。
